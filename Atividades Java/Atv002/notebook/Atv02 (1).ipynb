// %% [markdown]
// # Atv02

// %% [markdown]
// Exibir a mensagem “Informe um inteiro: “, deixando o cursor na mesma linha

// %%
System.out.print("Informe um interiro: ");
// Out:
// Informe um interiro:
// null

// %% [markdown]
// Atribuir o produto das variáveis b e c para a variável a

// %%
import java.util.Scanner;
Scanner ler = new Scanner(System.in);

int b = ler.nextInt();
int c = ler.nextInt();
int a = b*c;
System.out.printf("O produto entre %d e %d deu %d",b,c,a);
// Out:
// 3
// 9
// O produto entre 3 e 9 deu 27
// null

// %% [markdown]
// Demonstrar a execução do cálculo e utilizar um comentário para afirmar que é um programa de exemplo de folha de pagamento.

// %%
/*
    Receber o número um: 3
    Receber o número dois: 4
    Efetuar o cáculo, multiplicando os fatores
*/
